# %%
import numpy as np
import matplotlib.pyplot as plt
from sudoku import Sudoku
from dataset import SudokuDataset
from solvers import BasicSudokuIterativeSolver
from IPython.display import HTML, display

# %matplotlib inline

# %% [markdown]
# ## Solve a sudoku

# %%
unsolved, solved = SudokuDataset().get_sample(return_solution=True)

# %%
plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(121)
unsolved.draw()
plt.subplot(122)
solved.draw()

# %% [markdown]
# Lets solve the sudoku with our baseline algorithm...

# %%
solver = BasicSudokuIterativeSolver()
sudoku = unsolved.copy()
solver.solve(sudoku)

# %% [markdown]
# Now we compare it again with the real solution

# %%
plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(121)
sudoku.draw()
plt.subplot(122)
solution.draw()

# %% [markdown]
# ## Sudoku solving visualization

# %% [markdown]
# We can plot how the algorithm is solving the sudoku...

# %%
anim = solver.solve_animation(unsolved)
plt.close()
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgdf3d3f7d06e848af99bddadb83cf3b37">
#     <br>
#     <input id="_anim_sliderdf3d3f7d06e848af99bddadb83cf3b37" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animdf3d3f7d06e848af99bddadb83cf3b37.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animdf3d3f7d06e848af99bddadb83cf3b37.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectdf3d3f7d06e848af99bddadb83cf3b37" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdf3d3f7d06e848af99bddadb83cf3b37";
#     var slider_id = "_anim_sliderdf3d3f7d06e848af99bddadb83cf3b37";
#     var loop_select_id = "_anim_loop_selectdf3d3f7d06e848af99bddadb83cf3b37";
#     var frames = new Array(49);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAIABJREFUeJzt3XlQVOeePvCnvVB0s4hUgtjQLmDQ\
# OJmQ0cYNLaAgLlQETQgGJVEyGpiIWqRiZv7wjxsnmrhEcjF6R6xJuVyTkJAYF8KMYDBaSsqJzI2U\
# C0ZuIkt3CBewxwUQlPf3RwrmEuL8bOD0+/bp51PFH7wdfb6c4NOHt/twDEIIASIiUs4w2QMQEdFv\
# Y0ETESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGR\
# oljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1E\
# pCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkET\
# ESmKBU1EpCgWNBGRoljQRESKYkETESmKBU1EpCgWNBGRoljQRESKYkETESnKS/YAA2EwGGSPQEQ6\
# 9Mgjj6C5uVn2GL3csqABQAghJddgMHhcds8Toqd93TKzeczlHPNx48a5PPf/wi0OIiJFsaCJiBTF\
# giYiUhQLmohIUSxoIiJFeURB3759G2+++SaSk5NhNpthMBiQmZmpeW5mZiYMBsMDPzZt2qT5DDJc\
# uXIF6enpiIyMhL+/P4YPH47Jkydjx44d6OzslD0e6UxtbS0yMjIQHBwMo9GIp556Cvv27ZM91pBw\
# 27fZOaO5uRkbNmyA2WxGdHQ0iouLXZKbnZ2Np59+ut96fn4+zp8/j6SkJJfM4Wr19fVobW1Feno6\
# LBYL7t+/j7NnzyI3Nxfl5eU4fPiw7BFJJ2w2G6ZPn46Ojg6sWbMGZrMZx44dw8svvwyHw4Hc3FzZ\
# Iw6OcEPOjt3R0SEaGhqEEEJ0dXUJAGL58uUuyf61O3fuiICAAPHkk0+6PHugAAxJdk5OjgAgqqur\
# nc6Xxd2P+WDy3SE7JydHGAwGUVFR0Wc9OTlZ+Pn5iebmZqdyrVbrQ//3ruARWxw+Pj4ICwuTPQYA\
# 4IsvvsCtW7ewfPly2aO43NixYwEADodD8iSkF6dPn8b48eMxc+bMPusvvfQS7ty54/Y/rXlEQatk\
# //798PLywosvvih7FM21tbWhubkZ169fR2FhIbZu3Qqz2YyoqCjZo5FOdHZ2wtfXt9+6n58fAOD8\
# +fOuHmlIsaBdyGaz4auvvsK8efMQEhIiexzNbd26FcHBwQgPD8eSJUsQERGBkpISmEwm2aORTkyc\
# OBFXr15FY2Njn/WTJ08C+OXfnDtjQbvQn/70J3R3d7vkHSQqWLZsGcrKylBYWIjs7GwMGzaM2xs0\
# pHJycnD37l2kpqaioqICP/74I3bs2IHdu3cD+OWnOLcmexN8IAYztswXCSdNmiSCgoJER0eHy7MH\
# A0P0glVeXp7w9vYWly9fdjpfFnc/5oPJd5fsgoICERgY2HvMRowYIQ4cOCAAiEWLFjmVyxcJPdS3\
# 336LK1euYMmSJfDx8ZE9jhRLly5FV1cXDh48KHsU0pGsrCw0Njbi3LlzqKiogN1ux9SpUwEAEyZM\
# kDzd4HjE+6BVsH//fgDwyHdv9Ojo6AAA3LhxQ/IkpDdGoxHTpk3r/by0tBQAMHfuXFkjDQmeQbtA\
# Z2cnCgsLMWnSpD7fRHrV1NT0m+s9+4KecAxInp9++gmbN2+G1WpFQkKC7HEGxWPOoHfu3AmHw4Hu\
# 7m4AQFVVFTZu3AgASElJ0fStX8XFxWhpacEbb7yhWYZKsrOz0dLSgvj4eIwePRoOhwOlpaU4ceIE\
# YmJikJGRIXtE0onGxkYkJSVh0aJFsFgsqKurQ0FBAYQQOHjwoPvffUn2JvhADGTs

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# To evaluate our sudoku solving algorithm, use the method benchmark(). <br/> It will take n sudokus randomly from our dataset and solve each of them. Then calculate the accuracy and performance (how much sudokus solved succesfully and how much time needed the algorithm to solve one by mean)

# %%
metrics = solver.benchmark(n=20)
# Out:
# 100.00% accuracy        0.747 secs/sample       20 / 20

# %%
metrics
# Out:
# {'accuracy': 1.0, 'solve_time': 0.7470944046974182, 'failures': 0}
